# %% [markdown]
# # **2022 forbes billionaires** 🤑

# %% [markdown]
# # **Partie 1: Préparation**

# %% [markdown]
# Dans cette première partie, nous avons nettoyé les données.
# - Dans un premier temps nous avons travaillé avec python pour supprimer les cellules vides, certains caractères et les doublons s'il y en avait.
# Après avoir nettoyé on s'est retrouvé avec 2234 lignes au lieu de 2600.
# On a donc travaillé avec ces 2234 lignes. Mais on a vite constaté qu'il y'avait une incohérence par rapport aux résultats de dataviz obtenus. - - Ainsi on a nettoyé les données avec power BI et au final nous sommes restés à 2600 lignes comme à l'état initial après le nettoyage.
# Par la suite nous avons utilisé ces dernières données nettoyées pour les traiter.

# %% [markdown]
# **Import des bibliothèques pandas, matplotlib,seaborn**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Chargement des données dans un dataframe**

# %%
df1=pd.read_csv('/content/sample_data/2022_forbes_billionaires.csv', encoding = 'unicode_escape', engine ='python')

# %%
df1
# Out:
#                                              Unnamed: 0    rank  \
# 0     0,1,Elon Musk ,$219 B,50,United States,"Tesla,...     NaN
# 1                                                     1     2.0
# 2                                                     2     3.0
# 3                                                     3     4.0
# 4                                                     4     5.0
# ...                                                 ...     ...
# 2595                                               2595  2578.0
# 2596                                               2596  2578.0
# 2597                                               2597  2578.0
# 2598                                               2598  2578.0
# 2599                                               2599  2578.0
#
#                            name networth   age        country  \
# 0                          None     None   NaN           None
# 1                   Jeff Bezos    $171 B  58.0  United States
# ...

# %% [markdown]
# **Determination du nombre de lignes et de colonnes**

# %%
df1.shape
# Out:
# (2600, 8)

# %% [markdown]
# **Detection des valeurs manquantes**

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0      0
# rank          366
# name          366
# networth      366
# age           366
# country       366
# source        366
# industry      366
# dtype: int64

# %% [markdown]
# **Detection du nombre de duplicata**

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Danc ce dataset d'origine on constate qu'il y a 2600 lignes et 8 colones.
# Il y a aussi 366 valeur vide et dans la deuxième ligne les paramètres ne sont pas bien positionnés dans leurs colones.
#
# Je vais alors nettoyer les données avec un le logiciel Power BI

# %% [markdown]
# **Chargement des données nettoyées dans un dataframe et suppression de la première colonne**

# %%
df=pd.read_csv('/content/sample_data/data.csv', encoding = 'unicode_escape', engine ='python',quotechar='"', delimiter=';')

# %%
df.shape
# Out:
# (2600, 7)

# %% [markdown]
# **Affichage des datas**

# %%
df
# Out:
#       rank                      name  networth  age        country  \
# 0        1                 Elon Musk     219.0   50  United States
# 1        2                Jeff Bezos     171.0   58  United States
# 2        3  Bernard Arnault & family     158.0   73         France
# 3        4                Bill Gates     129.0   66  United States
# 4        5            Warren Buffett     118.0   91  United States
# ...    ...                       ...       ...  ...            ...
# 2595  2578              Nari Genomal       1.0   82    Philippines
# 2596  2578            Ramesh Genomal       1.0   71    Philippines
# 2597  2578            Sunder Genomal       1.0   68    Philippines
# 2598  2578               Vivien Chen       1.0   63      Hong Kong
# 2599  2578             Pollyanna Chu       1.0   64      Hong Kong
#
#                             source               industry
# 0                    Tesla, SpaceX             Automotive
# ...

# %% [markdown]
# **Suppression des caratères $ et B**
#
# La suppression de ces caratères a été fait au préalable sur Power BI

# %%
#df["networth"] = df["networth"].str.strip("$")
#df["networth"] = df["networth"].str.strip("B")
#df["networth"] = df["networth"].astype(float)

# %% [markdown]
# **Verification s'il y a encore des valeurs manquantes**

# %%
df.isnull().sum()
# Out:
# rank        0
# name        0
# networth    0
# age         0
# country     0
# source      0
# industry    0
# dtype: int64

# %% [markdown]
# **Suppression des doublons si ils existent**

# %%
df.drop_duplicates(keep = 'first', inplace=True)

# %%
df
# Out:
#       rank                      name  networth  age        country  \
# 0        1                 Elon Musk     219.0   50  United States
# 1        2                Jeff Bezos     171.0   58  United States
# 2        3  Bernard Arnault & family     158.0   73         France
# 3        4                Bill Gates     129.0   66  United States
# 4        5            Warren Buffett     118.0   91  United States
# ...    ...                       ...       ...  ...            ...
# 2595  2578              Nari Genomal       1.0   82    Philippines
# 2596  2578            Ramesh Genomal       1.0   71    Philippines
# 2597  2578            Sunder Genomal       1.0   68    Philippines
# 2598  2578               Vivien Chen       1.0   63      Hong Kong
# 2599  2578             Pollyanna Chu       1.0   64      Hong Kong
#
#                             source               industry
# 0                    Tesla, SpaceX             Automotive
# ...

# %% [markdown]
# **Description statistique du Dataframe**

# %%
df.describe()
# Out:
#               rank     networth          age
# count  2600.000000  2600.000000  2600.000000
# mean   1269.570769     4.860750    64.271923
# std     728.146364    10.659671    13.220607
# min       1.000000     1.000000    19.000000
# 25%     637.000000     1.500000    55.000000
# 50%    1292.000000     2.400000    64.000000
# 75%    1929.000000     4.500000    74.000000
# max    2578.000000   219.000000   100.000000

# %% [markdown]
# **Sauvegarder les Datas nettoyés**

# %%
df.to_csv('df.csv')

# %%
y = df['networth'].value_counts().head(5)
y_label=y.keys()
plt.bar(y_label,y, width=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Diagramme de corrélation
# Ce traitement nous permet de dire qu'il n'y pas de corrélation entre les différents paramètres numériques:âge, fortune et le rang.

# %%
import seaborn as sns
sns.heatmap(df.corr())
plt.savefig("Plotting_Correlation_HeatMap.jpg")

# %%
y = df['country'].value_counts().head(5)
y_label=y.keys()
plt.title('Top 5 des pays où il y a le plus de milliardaires')
plt.bar(y_label,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# D'apres ce graphique, il est clair que sur notre planète la concentration des milliardaires se situe aux USA, soit environ 700 individus sur notre population de 2600 personnes, suivi par la Chine. Il serait interessant de regrouper les 2 géants américains et chinois d'un coté et les autres pays de l'autre coté ( inde, allemagne, etc ....)car on voit une énorme différence de palier.

# %% [markdown]
# -------------------------------------------------------------------

# %%
y1 = df["country"].value_counts()
y_label1 =df["country"].value_counts().head(9).keys()
toplabel = [str(x) for x in y_label1]
toplabel.append("Autre")
l = [float(x)for x in y1]
top=[]
s= 0
for i in range (9):
    top.append(l[i])
    s += l[i]
top.append((sum(l) - s))
plt.pie(top, labels=toplabel, startangle=90)
plt.title("Top 10 des pays")
plt.show()

# %% [markdown]
# **Top 10 des secteurs d'activités où il y a plus de milliadaires**

# %%
y1 = df["industry"].value_counts()
y_label1 =df["industry"].value_counts().head(9).keys()
toplabel = [str(x) for x in y_label1]
toplabel.append("Autre")
l = [float(x)for x in y1]
top=[]
s= 0
for i in range (9):
    top.append(l[i])
    s += l[i]
top.append((sum(l) - s))
plt.pie(top, labels=toplabel, startangle=90)
plt.title("Top 10 des industries")
plt.show()

# %% [markdown]
# C'est dans la finance que retrouvons plus de milliadaires suivi du secteur de la tech et de l'industrie

# %% [markdown]
# ------------------------------------------------------------

# %% [markdown]
# Repartition des milliadaires selon la tranche d'âge

# %%
y = df['age'].value_counts().head(15)
y_label=y.keys()
plt.bar(y_label,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Les milliadaires sont majoritairements des individus âgés de 63 à 64 ans

# %% [markdown]
# -------------------------------------------------------

# %% [markdown]
# Top 10 des individus les plus riches

# %%
name = df['name'].head(10)
fw = df['networth'].head(10)

plt.bar(name, fw)
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# # **Partie 2: Prétraitement**

# %% [markdown]
# **Mise à l'echelle-Normalisation**

# %%
from sklearn.preprocessing import MaxAbsScaler, MinMaxScaler
scaler = MaxAbsScaler()
scaler.fit(df[['networth','age']])
scaled = scaler.transform(df[['networth','age']])
scaled_df = pd.DataFrame(scaled)
print(scaled_df)
# Out:
#              0     1
# 0     1.000000  0.50
# 1     0.780822  0.58
# 2     0.721461  0.73
# 3     0.589041  0.66
# 4     0.538813  0.91
# ...        ...   ...
# 2595  0.004566  0.82
# 2596  0.004566  0.71
# 2597  0.004566  0.68
# 2598  0.004566  0.63
# 2599  0.004566  0.64
#
# [2600 rows x 2 columns]

# %%
plt.scatter(scaled[:,0], scaled[:,1], color='red')

# %%
std_scaler = MinMaxScaler().fit(df[['networth', 'age']])
df_std = std_scaler.transform(df[['networth', 'age']])

# %%
print(df_std)
# Out:
# [[1.         0.38271605]
#  [0.77981651 0.48148148]
#  [0.72018349 0.66666667]
#  ...
#  [0.         0.60493827]
#  [0.         0.54320988]
#  [0.         0.55555556]]

# %%
minmax_scale = MinMaxScaler().fit(df[['networth', 'age']])
df_minmax = minmax_scale.transform(df[['networth', 'age']])

# %%
plt.scatter(df['networth'], df['age'],
            color='green', label='donnees sans transformations', alpha=0.5)
plt.scatter(df_minmax[:,0], df_minmax[:,1],
            color='red', label='min-max scaled [min=0, max=1]', alpha=0.3)
     
plt.scatter(df_std[:,0], df_std[:,1],
            color='blue', label='Standardisation vers la loi Normal X ~ N(0,1)', alpha=0.3)
plt.xlabel('networth')
plt.ylabel('age')
plt.show()

# %%
x = df[['networth', 'age']]
from sklearn.preprocessing import StandardScaler
mise_a_echelle = StandardScaler()
x = mise_a_echelle.fit_transform(x)
print(x)
# Out:
# [[20.09259468 -1.07972871]
#  [15.58877511 -0.47449635]
#  [14.36899065  0.66031433]
#  ...
#  [-0.36225253  0.2820441 ]
#  [-0.36225253 -0.09622613]
#  [-0.36225253 -0.02057208]]

# %%
plt.scatter(x[:,0], x[:,1], color='yellow')

# %%
fig = plt.figure(figsize=(16,9))
plt.title('Histogram Networth')
ax = sns.histplot(data=df[df['networth']>=df['networth'].quantile(q=0.99)]['networth'], kde=True, stat='density',bins = 7)
plt.xlabel("Networth")
plt.show()

# %% [markdown]
# # **Discrétisation en utilisant le groupement (Binning)**

# %% [markdown]
# **Création d'une nouvelle colonne pour regrouper les fortunes par catégorie: 'petite fortune',  'moyenne',  'grande fortune', 'Tres grande fortune'**

# %%
df['networth_bin']=pd.cut(df['networth'],
                        bins = [0,25,50,100,225], 
                        labels = ['petite fortune', 'moyenne', 'grande fortune','Tres grande fortune'])

# %%
df
# Out:
#       rank                      name  networth  age        country  \
# 0        1                 Elon Musk     219.0   50  United States
# 1        2                Jeff Bezos     171.0   58  United States
# 2        3  Bernard Arnault & family     158.0   73         France
# 3        4                Bill Gates     129.0   66  United States
# 4        5            Warren Buffett     118.0   91  United States
# ...    ...                       ...       ...  ...            ...
# 2595  2578              Nari Genomal       1.0   82    Philippines
# 2596  2578            Ramesh Genomal       1.0   71    Philippines
# 2597  2578            Sunder Genomal       1.0   68    Philippines
# 2598  2578               Vivien Chen       1.0   63      Hong Kong
# 2599  2578             Pollyanna Chu       1.0   64      Hong Kong
#
#                             source               industry         networth_bin
# 0                    Tesla, SpaceX             Automotive  Tres grande fortune
# ...

# %% [markdown]
# **Création d'une nouvelle colonne pour regrouper les milliadaires par catégorie d'âge:  'jeune',  'junior',  'senior', 'senior+'**

# %%
df['age_bin']=pd.cut(df['age'],
                        bins = [0,25,50,70,100], 
                        labels = ['jeune', 'junior', 'senior','senior+'])

# %%
df
# Out:
#       rank                      name  networth  age        country  \
# 0        1                 Elon Musk     219.0   50  United States
# 1        2                Jeff Bezos     171.0   58  United States
# 2        3  Bernard Arnault & family     158.0   73         France
# 3        4                Bill Gates     129.0   66  United States
# 4        5            Warren Buffett     118.0   91  United States
# ...    ...                       ...       ...  ...            ...
# 2595  2578              Nari Genomal       1.0   82    Philippines
# 2596  2578            Ramesh Genomal       1.0   71    Philippines
# 2597  2578            Sunder Genomal       1.0   68    Philippines
# 2598  2578               Vivien Chen       1.0   63      Hong Kong
# 2599  2578             Pollyanna Chu       1.0   64      Hong Kong
#
#                             source               industry  \
# 0                    Tesla, SpaceX             Automotive
# ...

# %%
y = df['age_bin'].value_counts()
y_label=y.keys()
plt.title("Nombre de milliardaires par catégorie d'âge")
plt.bar(y_label,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
y = df['networth_bin'].value_counts()
y_label=y.keys()
plt.title("Nombre de milliardaires par catégorie de fortune")
plt.bar(y_label,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
