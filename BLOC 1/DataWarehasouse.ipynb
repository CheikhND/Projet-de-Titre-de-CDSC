# %%
# !pip install boto3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 132 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 79 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 9.2 MB 16.5 MB/s
# ...
#      |████████████████████████████████| 140 kB 55.3 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.12 which is incompatible.
# ...

# %%
import json
import boto3
import pandas as pd
import pymongo
import csv

# %% [markdown]
# ## Connecter et lister tous les buckets

# %%
client = boto3.client('s3',
                      aws_access_key_id='AKIA47K7HWK72PN22H6F',
                      aws_secret_access_key='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',
                      region_name='eu-west-1')

# %%
# getting the s3 client
# offers connecting to the low-level client interface
client = boto3.client('s3',aws_access_key_id='AKIA47K7HWK72PN22H6F',
                      aws_secret_access_key='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',region_name='eu-west-1')

response = client.list_buckets()

for bucket in response['Buckets']:
    print('Bucket name= {}'.format(bucket['Name']))
    print('Creation date= {}'.format(bucket['CreationDate']))
    print('============')
# Out:
# Bucket name= bucket-cer
# Creation date= 2022-10-07 12:33:46+00:00
# ...
# Bucket name= cn-bucket
# Creation date= 2022-10-10 09:19:56+00:00
# ...

# %% [markdown]
# ## Afficher les métadonnées du Bucket

# %%
import boto3


response = client.list_objects(
    Bucket='bucket-cer'
)

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': '8G046SQ6XF7AAX5A',
#   'HostId': 'LKCHFoBYyA9w7cBv42cxuisj/jd8HBWIkvV3rpONgMIuig61d88hXmzxGxd3+TDMN+rgYZrWhjo=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'LKCHFoBYyA9w7cBv42cxuisj/jd8HBWIkvV3rpONgMIuig61d88hXmzxGxd3+TDMN+rgYZrWhjo=',
#    'x-amz-request-id': '8G046SQ6XF7AAX5A',
#    'date': 'Mon, 10 Oct 2022 09:26:57 GMT',
#    'x-amz-bucket-region': 'us-east-1',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 1},
#  'IsTruncated': False,
#  'Marker': '',
#  'Contents': [{'Key': 'data_lesparticuliers.csv',
#    'LastModified': datetime.datetime(2022, 10, 7, 13, 6, 25, tzinfo=tzlocal()),
#    'ETag': '"6271a6a6b10a4df2ded5da3a2d711fe4"',
#    'Size': 69379,
#    'StorageClass': 'STANDARD',
#    'Owner': {'DisplayName': 'cheikhndiaye02',
#     'ID': '408d666b014dda8c9a93908590f7b3b189892faa496f071a02f7e5df9b69cdd0'}},
# ...

# %% [markdown]
# ## Créer un Bucket

# %%
response = client.create_bucket(
    ACL='private',
    Bucket='buc-ket',
    CreateBucketConfiguration={
        'LocationConstraint': 'eu-west-1'
    }
)

print(response)
# Out:
# {'ResponseMetadata': {'RequestId': 'EMKFTMSSZBK7S04Y', 'HostId': 'J5RGOz7UL23DstL0CGA6UI7y5G8hO6ESUqr2aNDKjU86ADy+k2a3JLncJ0O9qWHrAP5dRrWQMB0=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'J5RGOz7UL23DstL0CGA6UI7y5G8hO6ESUqr2aNDKjU86ADy+k2a3JLncJ0O9qWHrAP5dRrWQMB0=', 'x-amz-request-id': 'EMKFTMSSZBK7S04Y', 'date': 'Mon, 10 Oct 2022 09:34:34 GMT', 'location': 'http://buc-ket.s3.amazonaws.com/', 'server': 'AmazonS3', 'content-length': '0'}, 'RetryAttempts': 0}, 'Location': 'http://buc-ket.s3.amazonaws.com/'}

# %% [markdown]
# ## Charger un fichier

# %%
file_name = '/content/sample_data/data_lesparticuliers.csv'
file_reader = open(file_name).read()

response = client.put_object(
    ACL='private',
    Bucket='buc-ket',
    Key=file_name,
    Body=file_reader
)

response
# Out:
# {'ResponseMetadata': {'RequestId': 'JXHF9VEV5ZC2DE6R',
#   'HostId': 'ZSQv49UVZOAH1Sq/tKiiR43IqmvQDHz5YQHU5ycYoJwyBcLAG6xXGoJsNbkXTPsrPDatKsihCsY=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'ZSQv49UVZOAH1Sq/tKiiR43IqmvQDHz5YQHU5ycYoJwyBcLAG6xXGoJsNbkXTPsrPDatKsihCsY=',
#    'x-amz-request-id': 'JXHF9VEV5ZC2DE6R',
#    'date': 'Mon, 10 Oct 2022 09:38:49 GMT',
#    'etag': '"6271a6a6b10a4df2ded5da3a2d711fe4"',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'ETag': '"6271a6a6b10a4df2ded5da3a2d711fe4"'}

# %%
obj = client.get_object(
    Bucket='buc-ket',
    Key = '/content/sample_data/data_lesparticuliers.csv'
)

# %%
print(obj)
# Out:
# {'ResponseMetadata': {'RequestId': 'QXAM2ZRFVJV054ZJ', 'HostId': 'uedjY6K3R2m4BoV/yU64i6XAhchsl0l3572/2m3NQJsMfMpVcA8ksRNk/xUB6PTp4UXu+QpXq7A=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'uedjY6K3R2m4BoV/yU64i6XAhchsl0l3572/2m3NQJsMfMpVcA8ksRNk/xUB6PTp4UXu+QpXq7A=', 'x-amz-request-id': 'QXAM2ZRFVJV054ZJ', 'date': 'Mon, 10 Oct 2022 09:42:05 GMT', 'last-modified': 'Mon, 10 Oct 2022 09:38:49 GMT', 'etag': '"6271a6a6b10a4df2ded5da3a2d711fe4"', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'server': 'AmazonS3', 'content-length': '69379'}, 'RetryAttempts': 0}, 'AcceptRanges': 'bytes', 'LastModified': datetime.datetime(2022, 10, 10, 9, 38, 49, tzinfo=tzutc()), 'ContentLength': 69379, 'ETag': '"6271a6a6b10a4df2ded5da3a2d711fe4"', 'ContentType': 'binary/octet-stream', 'Metadata': {}, 'Body': <botocore.response.StreamingBody object at 0x7f643dee8910>}

# %%
df =  pd.read_csv(obj['Body'])
print(df)
# Out:
#                                                Titre     Prix  \
# 0                                KIA PICANTO ESSENCE   7200 €
# 1                                       206+ essence   4200 €
# 2                                      Dacia essence   3200 €
# 3              A saisir, Twingo 2 places, 6500 euros   6500 €
# 4                                            Partner   2500 €
# ...                                              ...      ...
# 1243                               Occasion véhicule    450 €
# 1244  Mitsubishi L200 2 5 8 chevaux fiscaux 5 places  20500 €
# 1245             Dans l état pour pièce ou a réparer   1000 €
# 1246                    208 utilitaire 1l6 hdi 100ch   6000 €
# 1247                                          Kangoo   2000 €
#
#                          Ville        Date
# 0                   BOUILLANTE  20/09/2022
# 1                      CAYENNE  04/10/2022
# 2                      CAYENNE  04/10/2022
# 3                       KOUROU  04/10/2022
# ...

# %%
df
# Out:
#                                                Titre     Prix  \
# 0                                KIA PICANTO ESSENCE   7200 €
# 1                                       206+ essence   4200 €
# 2                                      Dacia essence   3200 €
# 3              A saisir, Twingo 2 places, 6500 euros   6500 €
# 4                                            Partner   2500 €
# ...                                              ...      ...
# 1243                               Occasion véhicule    450 €
# 1244  Mitsubishi L200 2 5 8 chevaux fiscaux 5 places  20500 €
# 1245             Dans l état pour pièce ou a réparer   1000 €
# 1246                    208 utilitaire 1l6 hdi 100ch   6000 €
# 1247                                          Kangoo   2000 €
#
#                          Ville        Date
# 0                   BOUILLANTE  20/09/2022
# 1                      CAYENNE  04/10/2022
# 2                      CAYENNE  04/10/2022
# 3                       KOUROU  04/10/2022
# ...

# %% [markdown]
# ## Nouvelle section

# %%
con = pymongo.MongoClient("mongodb://3.250.118.177:27017/")

# %%
db = con.dbfroms3

# %%
bucket_name='buc-ket'

# %%
client = boto3.client('s3',
                      aws_access_key_id='AKIA47K7HWK72PN22H6F',
                      aws_secret_access_key='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',
                      region_name='eu-west-1')

# %%
response = client.list_objects(
    Bucket = bucket_name
)

# %%
objectlist = [ content["Key"]for content in response['Contents']]
print(objectlist)
# Out:
# ['/content/sample_data/data_lesparticuliers.csv']

# %%
header = {
    "data_lesparticuliers":['userid','Titre','Prix','ville','Date']}

# %%
for objectx in objectlist:
    s3Object= client.get_object(
        Bucket= bucket_name,
        Key = objectx
    )
    for headx in header :
        if headx in objectx :
            hKey = headx
    if "tab" in objectx:
        sep='\t'
    else : sep='|'
    collection=objectx.split(";")[0]
    data = pd.DataFrame(pd.read_csv(s3Object['Body'],delimiter=sep,names=header [hKey],index_col=False))
    records=json.loads(data.T.to_json()).values()
    db[collection].insert_many(records)
    print(collection,'done')
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-60-11349658a9b5> in <module>
#      13     data = pd.DataFrame(pd.read_csv(s3Object['Body'],delimiter=sep,names=header [hKey],index_col=False))
#      14     records=json.loads(data.T.to_json()).values()
# ---> 15     db[collection].insert_many(records)
#      16     print(collection,'done')
#
# /usr/local/lib/python3.7/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     103                 with _TimeoutContext(timeout):
#     104                     return func(self, *args, **kwargs)
# --> 105         return func(self, *args, **kwargs)
#     106
#     107     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
# ...

# %%
df.isna().sum()
# Out:
# Titre    0
# Prix     9
# Ville    0
# Date     0
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)

# %%
df.shape
# Out:
# (1239, 4)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                                                Titre     Prix  \
# 0                                KIA PICANTO ESSENCE   7200 €
# 1                                       206+ essence   4200 €
# 2                                      Dacia essence   3200 €
# 3              A saisir, Twingo 2 places, 6500 euros   6500 €
# 4                                            Partner   2500 €
# ...                                              ...      ...
# 1243                               Occasion véhicule    450 €
# 1244  Mitsubishi L200 2 5 8 chevaux fiscaux 5 places  20500 €
# 1245             Dans l état pour pièce ou a réparer   1000 €
# 1246                    208 utilitaire 1l6 hdi 100ch   6000 €
# 1247                                          Kangoo   2000 €
#
#                          Ville        Date
# 0                   BOUILLANTE  20/09/2022
# 1                      CAYENNE  04/10/2022
# 2                      CAYENNE  04/10/2022
# 3                       KOUROU  04/10/2022
# ...
